# %% [markdown]
# <a href="https://colab.research.google.com/github/dhorvath/API-Pokemon/blob/master/Collab_101.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
import pandas as pd

# %%
from google.colab import files

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-41bad385-e558-45d4-ab0b-f214767829f8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-41bad385-e558-45d4-ab0b-f214767829f8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv('SDGE_Interconnected_Project_Sites_2024-03-31.csv')
# Out:
# <ipython-input-9-9c37c5dc7b57>:1: DtypeWarning: Columns (13,14,29,30,32,42,48,55,56,58,59,61,62,103,104,106,107,109,110,112,113,115,116,118,119,121,122,124,125) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('SDGE_Interconnected_Project_Sites_2024-03-31.csv')

# %%
df.head()
# Out:
#    Application Id  Matched CSI Application Number Application Status Utility  \
# 0      SDGE-INT-1                             NaN     Interconnected    SDGE
# 1     SDGE-INT-10                             NaN     Interconnected    SDGE
# 2    SDGE-INT-100                             NaN     Interconnected    SDGE
# 3   SDGE-INT-1000                             NaN     Interconnected    SDGE
# 4  SDGE-INT-10000                             NaN     Interconnected    SDGE
#
#      Service City  Service Zip Service County Technology Type  System Size DC  \
# 0  WARNER SPRINGS      92086.0      SAN DIEGO           Solar             2.5
# 1       SAN DIEGO      92123.0      SAN DIEGO           Solar             1.5
# 2       SAN DIEGO      92117.0      SAN DIEGO           Solar             3.2
# 3       SAN DIEGO      92127.0      SAN DIEGO           Solar             5.7
# 4    SANTA YSABEL      92070.0      SAN DIEGO           Solar             6.8
#
# ...

# %%
df.describe()
# Out:
#        Matched CSI Application Number    Service Zip  System Size DC  \
# count                             0.0  296883.000000   322232.000000
# mean                              NaN   92101.164728        8.482670
# std                               NaN     180.809466       42.922459
# min                               NaN   91901.000000        0.200000
# 25%                               NaN   92021.000000        4.345000
# 50%                               NaN   92069.000000        5.700000
# 75%                               NaN   92122.000000        8.000000
# max                               NaN   92694.000000     6850.000000
#
#        System Size AC  Storage Capacity (kWh)  Storage Size (kW AC)  \
# count   322232.000000            25168.000000          25168.000000
# mean         7.899952               11.472035              9.439012
# std         42.478683               75.857879             41.040107
# min          0.200000                0.280000              0.280000
# ...
